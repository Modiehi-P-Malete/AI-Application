# %%
# uv add --upgrade gradio  -> In your terminal

def greet(text):
    print(f"Shout has been called with input {text}")
    return text.upper()

greet("example text")
# Out:
# Shout has been called with input example text
# 'EXAMPLE TEXT'

# %%
# Adding share=True means that it can be accessed publically
# A more permanent hosting is available using a platform called Spaces from HuggingFace,
# NOTE: Some Anti-virus software and Corporate Firewalls might not like you using share=True. 
# If you're at work or on a work network, I suggest skip this test.


import gradio as gr

gr.Interface(fn=greet, inputs="textbox", outputs="textbox", flagging_mode="never").launch(share=True)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Patience\AppData\Local\Programs\Python\Python314\python.exe
