# %%
examples = """
input = [10, 5, 8] -> output = 23
input = [5, 2, 4] -> output = 11
input = [2, 1, 3] -> output = 6
input = [8, 4, 6] -> output = 18
"""

# Craft a prompt that asks the model for the function
prompt = f"""
Infer the Python function that maps the inputs to the outputs
using the examples provided below.

Examples:
```{examples}```

Generate:
- the Python function
- a short explanation of the logic
- an example demonstrating the function
"""

response = get_response(prompt)

print(response)
