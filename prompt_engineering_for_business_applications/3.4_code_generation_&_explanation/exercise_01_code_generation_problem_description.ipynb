# %%
# Craft a prompt that asks the model for the function definition to identify the month with the highest sales value from a list of monthly sales data.
prompt = f"""
Write a Python function that:
- receives a list of 12 floats representing monthly sales data
- identifies the month with the highest sales value
- returns the month with the highest sales value as output

Include:
- clear variable names
- comments explaining the logic
- an example function call
"""

response = get_response(prompt)

print(response)
