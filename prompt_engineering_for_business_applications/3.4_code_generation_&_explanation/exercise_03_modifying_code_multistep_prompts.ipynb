# %%
function = """
def calculate_area_rectangular_floor(width, length):
    return width * length
"""

# Craft a multi-step prompt that asks the model to adjust the function
prompt = f"""
Step 1:
Modify the provided Python function to validate that both width
and length are positive numbers.

Step 2:
If either value is zero or negative, display an appropriate
error message.

Step 3:
If the inputs are valid, calculate and return:
- the area of the rectangle
- the perimeter of the rectangle

Step 4:
Include example function calls demonstrating both valid
and invalid inputs.

Function:
```{function}```
"""

response = get_response(prompt)

print(response)
