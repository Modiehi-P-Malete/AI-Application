# %% [markdown]
# - Craft a prompt that expands the `product_description` pre-loaded string, and writes a **one paragraph** comprehensive overview capturing the key information of the product: **unique features**, **benefits**, and **potential applications**.

# %%
product_description = """
Smart home security camera with motion detection, night vision,
mobile app integration, cloud storage support, and two-way audio communication.
"""

prompt = f"""
Expand the product description from the pre-loaded string and write a one paragraph
comprehensive overview capturing the key information of the product:
unique features, benefits, and potential applications.

```{product_description}```
"""

response = get_response(prompt)

print("Original description:\n", product_description)
print("Expanded description:\n", response)
