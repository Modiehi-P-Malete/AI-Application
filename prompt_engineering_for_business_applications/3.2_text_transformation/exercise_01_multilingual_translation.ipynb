# %%
# Exercise 1: Translation for Multilingual Communication

marketing_message = """
Discover elegance redefined with our latest collection of premium leather handbags.
Crafted from the finest quality leather and designed with timeless sophistication,
each handbag blends luxury, durability, and modern style. Perfect for work,
travel, or special occasions, our new collection offers versatile designs that
elevate every outfit. Experience comfort, craftsmanship, and confidence—because
you deserve accessories as exceptional as you are.
"""

# Craft a prompt that translates the marketing message above into French, Spanish, and Japanese, ensuring that the translations are grammatically correct, natural-sounding, and suitable for professional marketing communication.
prompt = f"""
Translate the following marketing message from English into:
1. French
2. Spanish
3. Japanese

Ensure that each translation is grammatically correct, natural-sounding,
and suitable for professional marketing communication.

Marketing Message:
```{marketing_message}```
"""

response = get_response(prompt)

print("English:\n", marketing_message)
print("\nTranslations:\n", response)
