# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override=True)
openai_api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=openai_api_key)

# %% [markdown]
# ### Step 1: Defining the System Message
#
# This step sets the behavior of your assistant.

# %%
messages = [
    {"role": "system", "content": "You are a helpful Python tutor."} 
]

# %% [markdown]
# ### Step 2: Create User Questions
#
# We will be asking **multiple related questions**.

# %%
user_qs = ["Why is Python popular?","Summarize the above answer in one sentence."
]

# %% [markdown]
# ### Step 3: Loop Through Questions
#
# We want a response for **each question** we asked, so we use a loopto get that.

# %%
for question in user_qs:
    print(f"User Question: ${question}")
    user_message = {"role": "user", "content": question}

    messages.append(user_message)
    response = client.chat.completions.create(
        max_completion_tokens= 150,
        model="gpt-4.1-mini",
        messages=messages
    )

    print(messages)
    assistant_message = {"role": "assistant", "content": response.choices[0].message.content}
    messages.append(assistant_message)
    print(f"assistant_message: {response.choices[0].message.content}")
# Out:
# User Question: $Why is Python popular?
# [{'role': 'system', 'content': 'You are a helpful Python tutor.'}, {'role': 'user', 'content': 'Why is Python popular?'}]
# assistant_message: Python is popular for several reasons:
#
# 1. **Easy to Learn and Use**: Python has a simple and readable syntax that emphasizes readability, making it an excellent language for beginners.
#
# 2. **Versatility**: It can be used for web development, data science, artificial intelligence, automation, scientific computing, and more.
#
# 3. **Large Standard Library and Ecosystem**: Python comes with a comprehensive standard library and has a vast ecosystem of third-party packages available via PyPI (Python Package Index).
#
# 4. **Community Support**: A large and active community means plenty of tutorials, documentation, and forums where users can get help.
#
# 5. **Cross-Platform Compatibility**: Python runs on many operating systems, including Windows, macOS,
# ...
